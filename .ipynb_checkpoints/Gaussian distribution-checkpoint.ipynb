# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
from scipy.stats import multivariate_normal

x, y = np.mgrid[-3:3:30j, -3:3:30j]

# Need an (N, 2) array of (x, y) pairs.
xy = np.column_stack([x.flat, y.flat])

mu = np.array([0.0, 0.0])

Sigma = np.array([.5, .3]) # the covariance matrix
covariance = np.diag(Sigma)

z = multivariate_normal.pdf(xy, mean=mu, cov=covariance)

# Reshape back to a (30, 30) grid.
z = z.reshape(x.shape)

fig, ax = plt.subplots(subplot_kw={'projection': '3d'})

# ax.plot_surface(x,y,z)
l = ax.plot_wireframe(x,y,z, color='r')

plt.show()
print(type(l))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <class 'mpl_toolkits.mplot3d.art3d.Line3DCollection'>

# %%
i=15
j=15
print(z[i,j])
p = multivariate_normal.pdf([x[i,j],y[i,j]], mean=mu, cov=covariance)
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/wp/h8rtnsn576lgskrhkxzqnqg80000gn/T/ipykernel_90909/3058608844.py in <module>
#       1 i=15
#       2 j=15
# ----> 3 print(z[i,j])
#       4 p = multivariate_normal.pdf([x[i,j],y[i,j]], mean=mu, cov=covariance)
#       5 print(p)
#
# NameError: name 'z' is not defined

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.transform import Rotation as R

import numpy as np
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button, RadioButtons

import numpy as np
import matplotlib.pyplot as plt
# based on examples from Matplotlib docs

data = [[1,0,1], [0,1,0],[0,0,1]]
n_rows = len(data)
cell_text = []
for row in data:
    cell_text.append([f'{x:1.1f}' for x in row])
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
axt = fig.add_subplot()

# Add a table at the bottom of the axes
plt.sca(axt)
plt.gca().axis('off')
the_table = axt.table(cellText=cell_text,
                      # rowLabels=rows,
                      # rowColours=colors,
                      # colLabels=columns,
                      loc='bottom')

# Adjust layout to make room for the table:
plt.subplots_adjust(left=0.2, bottom=0.2, right=.8)

plt.sca(ax)
x, y = np.mgrid[-3:3:30j, -3:3:30j]
z = np.zeros(30*30).flatten().reshape(x.shape)
xyz = np.column_stack([x.flat, y.flat, z.flat])

r = R.from_euler('z', 0, degrees=True)
xyzr = (r.as_matrix() @ xyz.T).T
xr = xyzr[:,0].reshape(x.shape)
yr = xyzr[:,1].reshape(x.shape)
zr = xyzr[:,2].reshape(x.shape)

wf = ax.plot_wireframe(xr,yr,zr, color='r')
ax.margins(x=0)
ax.set_xlim(left=-6,right=6)
ax.set_ylim(bottom=-4,top=4)
ax.set_zlim(bottom=-4,top=4)

axcolor = 'r'

axthetaz = plt.axes([0.25, 0.25, 0.65, 0.03], facecolor=axcolor)
sthetaz = Slider(axthetaz, 'Alpha', -180, 180.0, valinit=0)
axthetax = plt.axes([0.25, 0.2, 0.65, 0.03], facecolor=axcolor)
sthetax = Slider(axthetax, 'Beta', 0, 180.0, valinit=0)
axthetay = plt.axes([0.25, 0.15, 0.65, 0.03], facecolor=axcolor)
sthetay = Slider(axthetay, 'Gamma', 0.1, 180.0, valinit=0)



def update(val):
    global wf
    thetax = sthetax.val
    thetay = sthetay.val
    thetaz = sthetaz.val
    r = R.from_euler('xyz', [thetax,thetay,thetaz], degrees=True)
    xyzr = (r.as_matrix() @ xyz.T).T
    xr = xyzr[:,0].reshape(x.shape)
    yr = xyzr[:,1].reshape(x.shape)
    zr = xyzr[:,2].reshape(x.shape)
    wf.remove()
    wf = ax.plot_wireframe(xr,yr,zr, color='r')
    # fig.canvas.draw_idle()


sthetax.on_changed(update)
sthetay.on_changed(update)
sthetaz.on_changed(update)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x.flatten
# Out:
# <function ndarray.flatten>

# %%
from scipy.spatial.transform import Rotation as R
r = R.from_euler('z', 90, degrees=True)
r.as_matrix()
# Out:
# array([[ 2.22044605e-16, -1.00000000e+00,  0.00000000e+00],
#        [ 1.00000000e+00,  2.22044605e-16,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]])

# %%
x, y = np.mgrid[-3:3:30j, -3:3:30j]
z = np.zeros(30*30).flatten().reshape(x.shape)
xyz = np.column_stack([x.flat, y.flat, z.flat])

# %%
xyz
# Out:
# array([[-3.        , -3.        ,  0.        ],
#        [-3.        , -2.79310345,  0.        ],
#        [-3.        , -2.5862069 ,  0.        ],
#        ...,
#        [ 3.        ,  2.5862069 ,  0.        ],
#        [ 3.        ,  2.79310345,  0.        ],
#        [ 3.        ,  3.        ,  0.        ]])
